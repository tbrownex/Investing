# %%
import pandas as pd

# %%
acct = 'summary_IRA'

# %%
dataLoc = '/home/tbrownex/data/retirement/accounts/'
df = pd.read_csv(dataLoc+acct+'.csv')
#spx = pd.read_csv(dataLoc+'/benchmark/summary.csv')

# %%
df.sort_values('annualGrowth')
# Out:
#      fund    var  annualGrowth
# 19  SKIRX  0.068        0.9104
# 2   PCLPX  0.073        0.9112
# 1   PHYTX  0.023        0.9909
# 6   PZTRX  0.022        0.9937
# 0   ANAYX  0.014        1.0037
# 7     VEA  0.053        1.0076
# 11  VAIPX  0.017        1.0106
# 17  GSDIX  0.030        1.0113
# 16  POSIX  0.056        1.0157
# 20  PONPX  0.014        1.0162
# 4   COIIX  0.054        1.0280
# 10    EFA  0.049        1.0394
# 18  MTIIX  0.037        1.0416
# 14  NFFFX  0.052        1.0518
# 8   VFIAX  0.043        1.0586
# 13  PIREX  0.061        1.0588
# 5   MEIIX  0.043        1.0593
# 22  total  0.033        1.0602
# 15  PRILX  0.040        1.0608
# 3     IJH  0.051        1.0856
# 21  COVRX  0.037        1.0901
# 12    IJR  0.056        1.0930
# 9   TRBCX  0.047        1.1075
