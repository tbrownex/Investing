# %%
import pandas as pd

# %%
dataLoc = '/home/tbrownex/data/retirement/funds/'
file = 'fundSummary.csv'
df = pd.read_csv(dataLoc+file)
#spx = pd.read_csv(dataLoc+'/benchmark/summary.csv')

# %%
df.sort_values('monthlyReturn')
# Out:
#      fund  volatilty  monthlyReturn
# 25  SKIRX    0.06803        0.99221
# 3   PCLPX    0.07298        0.99229
# 1   PHYTX    0.02253        0.99924
# 8   PZTRX    0.02238        0.99947
# 10   QYLD    0.03269        0.99995
# 23  NHMRX    0.02448        1.00003
# 0   ANAYX    0.01439        1.00031
# 11    VEA    0.05319        1.00064
# 19  TEAFX    0.01262        1.00087
# 15  VAIPX    0.01740        1.00088
# 22  GSDIX    0.02995        1.00094
# 21  POSIX    0.05612        1.00130
# 26  PONPX    0.01445        1.00134
# 5    RYLD    0.05868        1.00169
# 6   COIIX    0.05362        1.00230
# 2    NUSI    0.03703        1.00295
# 14    EFA    0.04888        1.00323
# 24  MTIIX    0.03651        1.00340
# 18  NFFFX    0.05178        1.00421
# 12  VFIAX    0.04343        1.00475
# 17  PIREX    0.06130        1.00477
# 7   MEIIX    0.04260        1.00481
# 20  PRILX    0.03984        1.00493
# 9     PEP    0.05530        1.00681
# 4     IJH    0.05102        1.00687
# ...

# %%
import numpy as np
ijr = round(1000*np.power(1.00744, 120))
ijh=round(1000*np.power(1.00687, 120))

print("IJR: ", ijr)
print("IJH: ", ijh)
print("IJR {:.2%} more than IJH over 20 years".format((ijr/ijh)-1))
# Out:
# IJR:  2434
# IJH:  2274
# IJR 7.04% more than IJH over 20 years
